# %%
from particle_filter.script.log import Log
from script.fingerprint import Fingerprint
from script.parameter import set_params
from datetime import datetime

# %%
set_params();
# Out:
# parameter.py: default.yaml has been loaded

# %%
begin = datetime(2021, 10, 28, 14, 10, 55)
end = datetime(2021, 10, 28, 15, 34, 55)

log = Log(begin, end)
fg = Fingerprint(log, begin, end)
# Out:
# log.py: 2021-10-28.csv has been loaded
# log.py: log length is 17109
# log.py: 66 beacons found
# fingerprint.py: the number of scan points is 84
# fingerprint.py: scan points has been loaded
# fingerprint.py: RSSI has been loaded

# %%
# fg.draw_points()
# fg.draw_beacons()
fg.show_with_heatmap(log, "a0:66:10:af:07:0d")
